# %% [markdown]
# <h2 style = "color:darkblue"> Projeto Mega - V7.JF </h2>
# <h3> Nova Análise Matemáticas incluindo numero do concurso sorteado</h3>
# <img src = "imagens/LogoJoao-2019.png" alt="Nada" style = "float:left;width:100px; height:100px">

# %%
# imports iniciais 
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from datetime import datetime
from IPython.core.display import HTML

# %matplotlib inline

# %%
df = pd.read_csv("data/dadosSomaDivMaxDivmin.csv")
df.drop("Unnamed: 0", axis=1, inplace=True)
df.head(5)
# Out:
#    Concurso  1ª Dezena  2ª Dezena  3ª Dezena  4ª Dezena  5ª Dezena  6ª Dezena  \
# 0       2.0        9.0       39.0       37.0       49.0       43.0       41.0
# 1       3.0       36.0       30.0       10.0       11.0       29.0       47.0
# 2      11.0       25.0       15.0       58.0       37.0       59.0       38.0
# 3      17.0       10.0       20.0        6.0       19.0       51.0       13.0
# 4      24.0        1.0        8.0       14.0       28.0       33.0       43.0
#
#     Soma  Divsqmax   Divsqmin  Divmedia
# 0  218.0  0.631884  10.380952  1.252047
# 1  163.0  0.472464   7.761905  0.936164
# 2  232.0  0.672464  11.047619  1.332454
# 3  119.0  0.344928   5.666667  0.683457
# 4  127.0  0.368116   6.047619  0.729404

# %%
df.sample(15)
# Out:
#      Concurso  1ª Dezena  2ª Dezena  3ª Dezena  4ª Dezena  5ª Dezena  \
# 309    1412.0        6.0        8.0       37.0       24.0       45.0
# 44      216.0       35.0       42.0       59.0       18.0       30.0
# 290    1354.0        2.0       42.0        8.0       49.0       48.0
# 151     740.0       29.0       47.0       12.0       50.0       16.0
# 45      218.0       54.0       40.0       42.0       17.0       47.0
# 52      245.0       44.0       51.0       27.0       53.0        8.0
# 136     647.0       56.0       19.0       11.0       14.0       12.0
# 153     753.0       59.0       35.0       43.0       22.0        7.0
# 94      457.0       48.0       15.0       24.0       27.0       17.0
# 215    1049.0       34.0       17.0       52.0        5.0        2.0
# 262    1237.0       26.0       21.0       39.0        5.0       18.0
# 185     932.0        2.0       21.0       42.0       53.0       36.0
# 438    1834.0        2.0       22.0       51.0       24.0       48.0
# 488    2081.0       40.0       42.0       13.0       18.0       35.0
# 391    1660.0       17.0       38.0       42.0       51.0       34.0
#
#      6ª Dezena   Soma  Divsqmax   Divsqmin  Divmedia
# 309       41.0  161.0  0.466667   7.666667  0.924677
# 44        14.0  198.0  0.573913   9.428571  1.137180
# 290       38.0  187.0  0.542029   8.904762  1.074004
# 151       28.0  182.0  0.527536   8.666667  1.045287
# 45        12.0  212.0  0.614493  10.095238  1.217587
# 52        60.0  243.0  0.704348  11.571429  1.395631
# 136       54.0  166.0  0.481159   7.904762  0.953394
# 153        2.0  168.0  0.486957   8.000000  0.964880
# 94        32.0  163.0  0.472464   7.761905  0.936164
# 215       29.0  139.0  0.402899   6.619048  0.798324
# 262       59.0  168.0  0.486957   8.000000  0.964880
# 185       17.0  171.0  0.495652   8.142857  0.982110
# 438       17.0  164.0  0.475362   7.809524  0.941907
# 488       41.0  189.0  0.547826   9.000000  1.085490
# 391        8.0  190.0  0.550725   9.047619  1.091234
